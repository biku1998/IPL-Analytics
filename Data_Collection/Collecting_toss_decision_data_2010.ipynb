# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import csv
import sys
pd.options.display.max_columns = 500
pd.options.display.max_rows = 500
from tqdm import tqdm_notebook as tqdm
import warnings
warnings.filterwarnings('ignore')
import traceback

# %%
def fetch_toss_data(years):
    
    Base_URL = ["http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?id=",";trophy=117;type=season"]
    if isinstance(years,list) == False or len(years) == 0:
        raise ValueError('Etiher the year is not passed in a list or the list is empty')
    
    # let's create dataFrames to store data
    columns = ['match_no','team 1','team 2','toss_info']

    df_toss = pd.DataFrame(columns = columns)

    try:


        # loop for all the years
        for year in years:
            # build the URL
            url = "http://www.espncricinfo.com/c/engine/series/418064.html"

            print(f'Collecting player data for year {year}....')

            source = requests.get(url).text

            soup = BeautifulSoup(source, 'lxml') 

            main_div = soup.find('div','news-pannel')

            link_all = main_div.find_all('a','potMatchMenuLink')
            useful_links = []
            # link_base = "http://stats.espncricinfo.com"

            for link in link_all:
                href = str(link['href'])
                if "https://www.espncricinfo.com/series/8048" in href:
                    useful_links.append(href)
                 
            for link in tqdm(useful_links):

                source = requests.get(link).text

                soup = BeautifulSoup(source, 'lxml')

                main_div = soup.find('div','col-b')

                # we will fetch step by step all the data

                # gp__cricket__gameHeader : it contains the following information ->
                # 1. match no, match city, match date
                # 2. team names, their scores,
                # 3. player of the match with team
                # 4. a small match summary : Super Kings won by 7 wickets (with 14 balls remaining)
                
                div_name = "gp__cricket__gameHeader"
                #################### scrape div_name = "gp__cricket__gameHeader" ####################
                div_gp__cricket__gameHeader_data = main_div.find('div',div_name)

                # print(div_gp__cricket__gameHeader_data.prettify())

                match_first_glance_info = div_gp__cricket__gameHeader_data.find('div','cscore_info-overview').text.strip()
                match_first_glance_info_parts = match_first_glance_info.split(',')
                
                match_no = match_first_glance_info_parts[0].split('s')[0] # attribute

                match_city = match_first_glance_info_parts[1].split('at')[1] # attribute

                date_parts = match_first_glance_info_parts[2].split(' ')

                month = date_parts[1] # attribute
                day = date_parts[2] # attribute
                year = date_parts[3] # attribute

                # print(month,day,year)

                # print(div_gp__cricket__gameHeader_data.prettify())

                # mom_details = div_gp__cricket__gameHeader_data.find('a','gp__cricket__player-match__player__detail__link').contents
                
                # mom_player_name = mom_details[0].strip() # attribute
                # mom_team_name = mom_details[1].text.strip() # attribute

                teams = div_gp__cricket__gameHeader_data.find_all('span','cscore_name cscore_name--long')
                # print(teams)
                team_1 = teams[0].text.strip() # attribute
                team_2 = teams[1].text.strip() # attribute
                # print(team_2)

                div_match_detail = main_div.find('div','match-detail-container')

                if div_match_detail is None:
                    continue

                # print(div_match_detail.prettify())

                div_left = div_match_detail.find_all('div','match-detail--left')[1]
                div_right = div_match_detail.find_all('div','match-detail--right')[1]

                toss_info = div_right.find('span').text.strip()
                # print(toss_info)
                # toss_winner_team = toss_info.split(',')[0]
                # toss_decision = toss_info.split(',')[1]

                # # columns = ['match_no','team 1','team 2','toss_winner','toss_decision']
                df_toss = df_toss.append({
                    'match_no':match_no,
                    'team 1':team_1,
                    'team 2':team_2,
                    'toss_info':toss_info
                },ignore_index = True)




                # print(df_toss)

                # return None

            
        return df_toss
    except Exception:
        traceback.print_exc()

# %%
df_toss = fetch_toss_data([2010])
# Out:
# Collecting player data for year 2010....
# HBox(children=(IntProgress(value=0, max=120), HTML(value='')))

# %%
df_toss
# Out:
#                   match_no                       team 1  \
# 0                        1        Kolkata Knight Riders
# 1          2nd match (D/N)               Mumbai Indians
# 2            3rd match (N)              Kings XI Punjab
# 3          4th match (D/N)  Royal Challengers Bangalore
# 4            5th match (N)              Deccan Chargers
# 5            6th match (N)             Rajasthan Royals
# 6          7th match (D/N)              Kings XI Punjab
# 7            8th match (N)          Chennai Super Kings
# 8            9th match (N)               Mumbai Indians
# 9           10th match (N)             Rajasthan Royals
# 10        11th match (D/N)             Delhi Daredevils
# 11          12th match (N)              Deccan Chargers
# 12        13th match (D/N)             Rajasthan Royals
# 13          14th match (N)               Mumbai Indians
# 14        15th match (D/N)              Deccan Chargers
# 15          16th match (N)              Kings XI Punjab
# 16          17th match (N)        Kolkata Knight Riders
# 17          18th match (N)  Royal Challengers Bangalore
# 18          19th match (N)             Rajasthan Royals
# 19        20th match (D/N)             Delhi Daredevils
# 20                      21          Chennai Super Kings
# 21          22nd match (N)              Deccan Chargers
# 22          23rd match (N)        Kolkata Knight Riders
# 23        24th match (D/N)             Rajasthan Royals
# 24          25th match (N)               Mumbai Indians
# 25          26th match (N)             Delhi Daredevils
# 26          27th match (N)              Kings XI Punjab
# 27        28th match (D/N)  Royal Challengers Bangalore
# 28          29th match (N)             Delhi Daredevils
# 29          30th match (N)        Kolkata Knight Riders
# 30                      31              Kings XI Punjab
# 31        32nd match (D/N)          Chennai Super Kings
# 32          33rd match (N)               Mumbai Indians
# 33        34th match (D/N)        Kolkata Knight Riders
# 34          35th match (N)             Delhi Daredevils
# 35          36th match (N)             Rajasthan Royals
# 36          37th match (N)          Chennai Super Kings
# 37        38th match (D/N)              Kings XI Punjab
# 38          39th match (N)        Kolkata Knight Riders
# 39          40th match (N)  Royal Challengers Bangalore
# 40                      41               Mumbai Indians
# 41        42nd match (D/N)          Chennai Super Kings
# 42          43rd match (N)        Kolkata Knight Riders
# 43        44th match (D/N)             Delhi Daredevils
# 44          45th match (N)               Mumbai Indians
# 45          46th match (N)              Deccan Chargers
# 46        47th match (D/N)               Mumbai Indians
# 47          48th match (N)        Kolkata Knight Riders
# 48          49th match (N)             Rajasthan Royals
# 49          50th match (N)          Chennai Super Kings
# 50                      51              Kings XI Punjab
# 51        52nd match (D/N)               Mumbai Indians
# 52          53rd match (N)             Rajasthan Royals
# 53        54th match (D/N)              Kings XI Punjab
# 54          55th match (N)              Deccan Chargers
# 55          56th match (N)               Mumbai Indians
# 56                       1               Mumbai Indians
# 57      2nd Semi-Final (N)          Chennai Super Kings
# 58  3rd Place Play-off (N)              Deccan Chargers
# 59               Final (N)          Chennai Super Kings
#
#                          team 2  \
# 0               Deccan Chargers
# 1              Rajasthan Royals
# 2              Delhi Daredevils
# 3         Kolkata Knight Riders
# 4           Chennai Super Kings
# 5              Delhi Daredevils
# 6   Royal Challengers Bangalore
# 7         Kolkata Knight Riders
# 8              Delhi Daredevils
# 9   Royal Challengers Bangalore
# 10          Chennai Super Kings
# 11              Kings XI Punjab
# 12        Kolkata Knight Riders
# 13  Royal Challengers Bangalore
# 14             Delhi Daredevils
# 15          Chennai Super Kings
# 16               Mumbai Indians
# 17          Chennai Super Kings
# 18              Kings XI Punjab
# 19  Royal Challengers Bangalore
# 20               Mumbai Indians
# 21             Rajasthan Royals
# 22              Kings XI Punjab
# 23          Chennai Super Kings
# 24              Deccan Chargers
# 25        Kolkata Knight Riders
# 26               Mumbai Indians
# 27          Chennai Super Kings
# 28             Rajasthan Royals
# 29              Deccan Chargers
# 30  Royal Challengers Bangalore
# 31             Rajasthan Royals
# 32              Deccan Chargers
# 33              Kings XI Punjab
# 34  Royal Challengers Bangalore
# 35              Deccan Chargers
# 36               Mumbai Indians
# 37             Rajasthan Royals
# 38             Delhi Daredevils
# 39              Deccan Chargers
# 40              Kings XI Punjab
# 41              Deccan Chargers
# 42  Royal Challengers Bangalore
# 43              Kings XI Punjab
# 44             Rajasthan Royals
# 45  Royal Challengers Bangalore
# 46             Delhi Daredevils
# 47          Chennai Super Kings
# 48  Royal Challengers Bangalore
# 49             Delhi Daredevils
# 50              Deccan Chargers
# 51  Royal Challengers Bangalore
# 52        Kolkata Knight Riders
# 53          Chennai Super Kings
# 54             Delhi Daredevils
# 55        Kolkata Knight Riders
# 56  Royal Challengers Bangalore
# 57              Deccan Chargers
# 58  Royal Challengers Bangalore
# 59               Mumbai Indians
#
#                                             toss_info
# 0            Deccan Chargers , elected to field first
# 1               Mumbai Indians , elected to bat first
# 2           Delhi Daredevils , elected to field first
# 3      Kolkata Knight Riders , elected to field first
# 4              Deccan Chargers , elected to bat first
# 5           Delhi Daredevils , elected to field first
# 6              Kings XI Punjab , elected to bat first
# 7          Chennai Super Kings , elected to bat first
# 8           Delhi Daredevils , elected to field first
# 9   Royal Challengers Bangalore , elected to field...
# 10            Delhi Daredevils , elected to bat first
# 11           Kings XI Punjab , elected to field first
# 12            Rajasthan Royals , elected to bat first
# 13              Mumbai Indians , elected to bat first
# 14             Deccan Chargers , elected to bat first
# 15       Chennai Super Kings , elected to field first
# 16       Kolkata Knight Riders , elected to bat first
# 17       Chennai Super Kings , elected to field first
# 18           Kings XI Punjab , elected to field first
# 19  Royal Challengers Bangalore , elected to field...
# 20            Mumbai Indians , elected to field first
# 21             Deccan Chargers , elected to bat first
# 22       Kolkata Knight Riders , elected to bat first
# 23            Rajasthan Royals , elected to bat first
# 24           Deccan Chargers , elected to field first
# 25            Delhi Daredevils , elected to bat first
# 26            Mumbai Indians , elected to field first
# 27  Royal Challengers Bangalore , elected to bat f...
# 28            Delhi Daredevils , elected to bat first
# 29       Kolkata Knight Riders , elected to bat first
# 30             Kings XI Punjab , elected to bat first
# 31         Chennai Super Kings , elected to bat first
# 32              Mumbai Indians , elected to bat first
# 33       Kolkata Knight Riders , elected to bat first
# 34            Delhi Daredevils , elected to bat first
# 35            Rajasthan Royals , elected to bat first
# 36         Chennai Super Kings , elected to bat first
# 37             Kings XI Punjab , elected to bat first
# 38       Kolkata Knight Riders , elected to bat first
# 39           Deccan Chargers , elected to field first
# 40              Mumbai Indians , elected to bat first
# 41         Chennai Super Kings , elected to bat first
# 42  Royal Challengers Bangalore , elected to field...
# 43            Delhi Daredevils , elected to bat first
# 44          Rajasthan Royals , elected to field first
# 45  Royal Challengers Bangalore , elected to field...
# 46              Mumbai Indians , elected to bat first
# 47       Kolkata Knight Riders , elected to bat first
# 48            Rajasthan Royals , elected to bat first
# 49         Chennai Super Kings , elected to bat first
# 50           Deccan Chargers , elected to field first
# 51  Royal Challengers Bangalore , elected to field...
# 52            Rajasthan Royals , elected to bat first
# 53       Chennai Super Kings , elected to field first
# 54             Deccan Chargers , elected to bat first
# 55              Mumbai Indians , elected to bat first
# 56              Mumbai Indians , elected to bat first
# 57         Chennai Super Kings , elected to bat first
# 58             Deccan Chargers , elected to bat first
# 59         Chennai Super Kings , elected to bat first

# %%
df_toss.to_csv('/content/drive/My Drive/data/toss_data_2010.csv',index=False)
