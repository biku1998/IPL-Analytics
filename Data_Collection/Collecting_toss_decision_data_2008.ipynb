# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import csv
import sys
pd.options.display.max_columns = 500
pd.options.display.max_rows = 500
from tqdm import tqdm_notebook as tqdm
import warnings
warnings.filterwarnings('ignore')
import traceback

# %%
def fetch_toss_data(years):
    
    Base_URL = ["http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?id=",";trophy=117;type=season"]
    if isinstance(years,list) == False or len(years) == 0:
        raise ValueError('Etiher the year is not passed in a list or the list is empty')
    
    # let's create dataFrames to store data
    columns = ['match_no','team 1','team 2','toss_info']

    df_toss = pd.DataFrame(columns = columns)

    try:


        # loop for all the years
        for year in years:
            # build the URL
            url = "http://www.espncricinfo.com/c/engine/series/313494.html"

            print(f'Collecting player data for year {year}....')

            source = requests.get(url).text

            soup = BeautifulSoup(source, 'lxml') 

            main_div = soup.find('div','news-pannel')

            link_all = main_div.find_all('a','potMatchMenuLink')
            useful_links = []
            # link_base = "http://stats.espncricinfo.com"

            for link in link_all:
                href = str(link['href'])
                if "https://www.espncricinfo.com/series/8048" in href:
                    useful_links.append(href)
                 
            for link in tqdm(useful_links):

                source = requests.get(link).text

                soup = BeautifulSoup(source, 'lxml')

                main_div = soup.find('div','col-b')

                # we will fetch step by step all the data

                # gp__cricket__gameHeader : it contains the following information ->
                # 1. match no, match city, match date
                # 2. team names, their scores,
                # 3. player of the match with team
                # 4. a small match summary : Super Kings won by 7 wickets (with 14 balls remaining)
                
                div_name = "gp__cricket__gameHeader"
                #################### scrape div_name = "gp__cricket__gameHeader" ####################
                div_gp__cricket__gameHeader_data = main_div.find('div',div_name)

                # print(div_gp__cricket__gameHeader_data.prettify())

                match_first_glance_info = div_gp__cricket__gameHeader_data.find('div','cscore_info-overview').text.strip()
                match_first_glance_info_parts = match_first_glance_info.split(',')
                
                match_no = match_first_glance_info_parts[0].split('s')[0] # attribute

                match_city = match_first_glance_info_parts[1].split('at')[1] # attribute

                date_parts = match_first_glance_info_parts[2].split(' ')

                month = date_parts[1] # attribute
                day = date_parts[2] # attribute
                year = date_parts[3] # attribute

                # print(month,day,year)

                # print(div_gp__cricket__gameHeader_data.prettify())

                # mom_details = div_gp__cricket__gameHeader_data.find('a','gp__cricket__player-match__player__detail__link').contents
                
                # mom_player_name = mom_details[0].strip() # attribute
                # mom_team_name = mom_details[1].text.strip() # attribute

                teams = div_gp__cricket__gameHeader_data.find_all('span','cscore_name cscore_name--long')
                # print(teams)
                team_1 = teams[0].text.strip() # attribute
                team_2 = teams[1].text.strip() # attribute
                # print(team_2)

                div_match_detail = main_div.find('div','match-detail-container')

                if div_match_detail is None:
                    continue

                # print(div_match_detail.prettify())

                div_left = div_match_detail.find_all('div','match-detail--left')[1]
                div_right = div_match_detail.find_all('div','match-detail--right')[1]

                toss_info = div_right.find('span').text.strip()
                # print(toss_info)
                # toss_winner_team = toss_info.split(',')[0]
                # toss_decision = toss_info.split(',')[1]

                # # columns = ['match_no','team 1','team 2','toss_winner','toss_decision']
                df_toss = df_toss.append({
                    'match_no':match_no,
                    'team 1':team_1,
                    'team 2':team_2,
                    'toss_info':toss_info
                },ignore_index = True)




                # print(df_toss)

                # return None

            
        return df_toss
    except Exception:
        traceback.print_exc()

# %%
df_toss = fetch_toss_data([2008])
# Out:
# Collecting player data for year 2008....
# HBox(children=(IntProgress(value=0, max=118), HTML(value='')))

# %%
df_toss
# Out:
#               match_no                       team 1  \
# 0                    1        Kolkata Knight Riders
# 1      2nd match (D/N)          Chennai Super Kings
# 2        3rd match (N)             Rajasthan Royals
# 3      4th match (D/N)              Deccan Chargers
# 4        5th match (N)               Mumbai Indians
# 5        6th match (N)              Kings XI Punjab
# 6        7th match (N)              Deccan Chargers
# 7        8th match (N)          Chennai Super Kings
# 8        9th match (N)              Deccan Chargers
# 9       10th match (N)              Kings XI Punjab
# 10    11th match (D/N)        Kolkata Knight Riders
# 11      12th match (N)  Royal Challengers Bangalore
# 12    13th match (D/N)             Delhi Daredevils
# 13      14th match (N)               Mumbai Indians
# 14      15th match (N)          Chennai Super Kings
# 15      16th match (N)        Kolkata Knight Riders
# 16      17th match (N)             Delhi Daredevils
# 17    18th match (D/N)             Rajasthan Royals
# 18      19th match (N)              Deccan Chargers
# 19      20th match (N)          Chennai Super Kings
# 20                  21  Royal Challengers Bangalore
# 21      22nd match (N)              Kings XI Punjab
# 22    23rd match (D/N)               Mumbai Indians
# 23      24th match (N)          Chennai Super Kings
# 24      25th match (N)  Royal Challengers Bangalore
# 25      26th match (N)          Chennai Super Kings
# 26      27th match (N)             Rajasthan Royals
# 27    28th match (D/N)             Delhi Daredevils
# 28      29th match (N)        Kolkata Knight Riders
# 29      30th match (N)              Deccan Chargers
# 30                  31          Chennai Super Kings
# 31    32nd match (D/N)        Kolkata Knight Riders
# 32      33rd match (N)             Delhi Daredevils
# 33      34th match (N)  Royal Challengers Bangalore
# 34      35th match (N)        Kolkata Knight Riders
# 35      36th match (N)          Chennai Super Kings
# 36      37th match (N)             Delhi Daredevils
# 37      38th match (N)        Kolkata Knight Riders
# 38    39th match (D/N)             Rajasthan Royals
# 39      40th match (N)             Delhi Daredevils
# 40                  41        Kolkata Knight Riders
# 41      42nd match (N)               Mumbai Indians
# 42      43rd match (N)  Royal Challengers Bangalore
# 43      44th match (N)        Kolkata Knight Riders
# 44    45th match (D/N)              Kings XI Punjab
# 45      46th match (N)  Royal Challengers Bangalore
# 46      47th match (N)             Delhi Daredevils
# 47      48th match (N)              Deccan Chargers
# 48    49th match (D/N)             Rajasthan Royals
# 49      50th match (N)               Mumbai Indians
# 50                  51              Deccan Chargers
# 51      52nd match (N)              Kings XI Punjab
# 52      53rd match (N)               Mumbai Indians
# 53      54th match (N)              Deccan Chargers
# 54    55th match (D/N)  Royal Challengers Bangalore
# 55      56th match (N)              Kings XI Punjab
# 56                   1             Rajasthan Royals
# 57  2nd Semi-Final (N)              Kings XI Punjab
# 58           Final (N)          Chennai Super Kings
#
#                          team 2  \
# 0   Royal Challengers Bangalore
# 1               Kings XI Punjab
# 2              Delhi Daredevils
# 3         Kolkata Knight Riders
# 4   Royal Challengers Bangalore
# 5              Rajasthan Royals
# 6              Delhi Daredevils
# 7                Mumbai Indians
# 8              Rajasthan Royals
# 9                Mumbai Indians
# 10          Chennai Super Kings
# 11             Rajasthan Royals
# 12              Kings XI Punjab
# 13              Deccan Chargers
# 14  Royal Challengers Bangalore
# 15               Mumbai Indians
# 16  Royal Challengers Bangalore
# 17        Kolkata Knight Riders
# 18              Kings XI Punjab
# 19             Delhi Daredevils
# 20              Deccan Chargers
# 21        Kolkata Knight Riders
# 22             Delhi Daredevils
# 23             Rajasthan Royals
# 24              Kings XI Punjab
# 25              Deccan Chargers
# 26               Mumbai Indians
# 27          Chennai Super Kings
# 28  Royal Challengers Bangalore
# 29             Rajasthan Royals
# 30              Kings XI Punjab
# 31              Deccan Chargers
# 32             Rajasthan Royals
# 33              Kings XI Punjab
# 34             Delhi Daredevils
# 35               Mumbai Indians
# 36              Deccan Chargers
# 37               Mumbai Indians
# 38  Royal Challengers Bangalore
# 39              Kings XI Punjab
# 40          Chennai Super Kings
# 41              Deccan Chargers
# 42             Delhi Daredevils
# 43             Rajasthan Royals
# 44               Mumbai Indians
# 45          Chennai Super Kings
# 46        Kolkata Knight Riders
# 47              Kings XI Punjab
# 48          Chennai Super Kings
# 49             Delhi Daredevils
# 50  Royal Challengers Bangalore
# 51        Kolkata Knight Riders
# 52             Rajasthan Royals
# 53          Chennai Super Kings
# 54               Mumbai Indians
# 55             Rajasthan Royals
# 56             Delhi Daredevils
# 57          Chennai Super Kings
# 58             Rajasthan Royals
#
#                                             toss_info
# 0   Royal Challengers Bangalore , elected to field...
# 1          Chennai Super Kings , elected to bat first
# 2             Rajasthan Royals , elected to bat first
# 3              Deccan Chargers , elected to bat first
# 4               Mumbai Indians , elected to bat first
# 5              Kings XI Punjab , elected to bat first
# 6              Deccan Chargers , elected to bat first
# 7             Mumbai Indians , elected to field first
# 8           Rajasthan Royals , elected to field first
# 9             Mumbai Indians , elected to field first
# 10       Kolkata Knight Riders , elected to bat first
# 11          Rajasthan Royals , elected to field first
# 12            Delhi Daredevils , elected to bat first
# 13           Deccan Chargers , elected to field first
# 14         Chennai Super Kings , elected to bat first
# 15       Kolkata Knight Riders , elected to bat first
# 16  Royal Challengers Bangalore , elected to field...
# 17            Rajasthan Royals , elected to bat first
# 18           Kings XI Punjab , elected to field first
# 19         Chennai Super Kings , elected to bat first
# 20           Deccan Chargers , elected to field first
# 21             Kings XI Punjab , elected to bat first
# 22          Delhi Daredevils , elected to field first
# 23         Chennai Super Kings , elected to bat first
# 24           Kings XI Punjab , elected to field first
# 25           Deccan Chargers , elected to field first
# 26            Mumbai Indians , elected to field first
# 27       Chennai Super Kings , elected to field first
# 28       Kolkata Knight Riders , elected to bat first
# 29          Rajasthan Royals , elected to field first
# 30           Kings XI Punjab , elected to field first
# 31       Kolkata Knight Riders , elected to bat first
# 32          Rajasthan Royals , elected to field first
# 33  Royal Challengers Bangalore , elected to bat f...
# 34       Kolkata Knight Riders , elected to bat first
# 35            Mumbai Indians , elected to field first
# 36           Deccan Chargers , elected to field first
# 37            Mumbai Indians , elected to field first
# 38  Royal Challengers Bangalore , elected to field...
# 39            Delhi Daredevils , elected to bat first
# 40       Kolkata Knight Riders , elected to bat first
# 41           Deccan Chargers , elected to field first
# 42          Delhi Daredevils , elected to field first
# 43          Rajasthan Royals , elected to field first
# 44            Mumbai Indians , elected to field first
# 45  Royal Challengers Bangalore , elected to bat f...
# 46                                            no toss
# 47           Kings XI Punjab , elected to field first
# 48            Rajasthan Royals , elected to bat first
# 49          Delhi Daredevils , elected to field first
# 50             Deccan Chargers , elected to bat first
# 51             Kings XI Punjab , elected to bat first
# 52          Rajasthan Royals , elected to field first
# 53             Deccan Chargers , elected to bat first
# 54            Mumbai Indians , elected to field first
# 55          Rajasthan Royals , elected to field first
# 56          Delhi Daredevils , elected to field first
# 57             Kings XI Punjab , elected to bat first
# 58          Rajasthan Royals , elected to field first

# %%
df_toss.to_csv('/content/drive/My Drive/data/toss_data_2008.csv',index=False)
