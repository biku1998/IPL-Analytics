# %%
import pandas as pd
import numpy as np
import pyodbc
import json
import warnings
from tqdm import tqdm_notebook as tqdm
warnings.filterwarnings('ignore')

# %%
df_match_batting = pd.read_csv('E:/Google_Drive_Contents/data/Batsmen_scorecard_data.csv')

# %%
df_match_batting.head()
# Out:
#   match_no match_city  year  month day          team_1               team_2  \
# 0        1  Cape Town  2009  April  18  Mumbai Indians  Chennai Super Kings
# 1        1  Cape Town  2009  April  18  Mumbai Indians  Chennai Super Kings
# 2        1  Cape Town  2009  April  18  Mumbai Indians  Chennai Super Kings
# 3        1  Cape Town  2009  April  18  Mumbai Indians  Chennai Super Kings
# 4        1  Cape Town  2009  April  18  Mumbai Indians  Chennai Super Kings
#
#             batsmen               wicket_status   R     B    M  fours  sixes  \
# 0     ST Jayasuriya         c Hayden b Thushara  26  20.0  NaN    5.0    0.0
# 1  SR Tendulkar (c)                     not out  59  49.0  NaN    7.0    0.0
# 2          S Dhawan              c Dhoni b Gony  22  21.0  NaN    2.0    0.0
# 3         JP Duminy                  c & b Gony   9   7.0  NaN    1.0    0.0
# 4          DJ Bravo  c Hayden b Joginder Sharma   5   4.0  NaN    1.0    0.0
#
#        SR   special_role
# 0  130.00  normal player
# 1  120.40        captain
# 2  104.76  normal player
# 3  128.57  normal player
# 4  125.00  normal player

# %%
# Let's add some new columns

# creating dismissal mode

def extract_dismissal(wkt_info):
    """
    this function will extract dismissal form from the wkt_info.
    """
    if wkt_info != None and wkt_info.strip().split(' ')[0] == 'c':
        return "caught"
    elif wkt_info != None and wkt_info.strip().split(' ')[0] == 'b':
        return "bowled"
    elif wkt_info != None and wkt_info.strip().split(' ')[0] == 'st':
        return "stumped"
    elif wkt_info != None and wkt_info.strip().split(' ')[0] == 'lbw':
        return "lbw"
    elif wkt_info != None and wkt_info.strip().split(' ')[0] == 'run':
        return "run out"
    elif wkt_info != None and wkt_info.strip().split(' ')[0] == 'not':
        return "not out"
    elif wkt_info != None and wkt_info.strip().split(' ')[0] == 'retired':
        return "retired"
    elif wkt_info != None and wkt_info.strip().split(' ')[0] == 'obstructing':
        return "Obstructing the field"
    elif wkt_info != None and wkt_info.strip().split(' ')[0] == 'hit':
        return "hit wicket"
    else:
        return wkt_info

df_match_batting['dismissal_mode'] = df_match_batting['wicket_status'].apply(extract_dismissal)
df_match_batting['dismissal_mode'].unique()
# Out:
# array(['caught', 'not out', 'run out', 'bowled', 'stumped', 'lbw',
#        'absent hurt', 'hit wicket', 'retired', 'Obstructing the field'],
#       dtype=object)

# %%
df_match_batting.columns
# Out:
# Index(['match_no', 'match_city', 'year', 'month', 'day', 'team_1', 'team_2',
#        'batsmen', 'wicket_status', 'R', 'B', 'M', 'fours', 'sixes', 'SR',
#        'special_role', 'dismissal_mode'],
#       dtype='object')

# %%
df_match_batting['month'].unique()
# Out:
# array(['April', 'May', 'June', 'March', 'Apr', 'Jun'], dtype=object)

# %%
# some data_cleaning_steps for year 2008

filter_ = df_match_batting['year'] == 2008

def month_map(month):
    month_map_dict = {'Apr':'April','May':'May','Jun':'June','Mar':'March'}
    if month in month_map_dict.keys():
        return month_map_dict[month]
    else:
        return month
    
    

df_match_batting['month'] = df_match_batting['month'].apply(month_map)


def filter_special_players(player):
    if '(c)' in player:
        return 'captain'
    elif '†' in player:
        return 'wicket keeper'
    else:
        return 'normal player'

df_match_batting['special_role'] = df_match_batting['batsmen'].apply(filter_special_players)

# %%
# to make sure we don't have extra spaces in any of the string columns

df_match_batting['match_city'] = df_match_batting['match_city'].apply(lambda x : x.strip())
df_match_batting['team_1'] = df_match_batting['team_1'].apply(lambda x : x.strip())
df_match_batting['team_2'] = df_match_batting['team_2'].apply(lambda x : x.strip())
df_match_batting['batsmen']  = df_match_batting['batsmen'].apply(lambda x : x.strip())
df_match_batting['wicket_status'] = df_match_batting['wicket_status'].apply(lambda x : x.strip())

# %%
# let's also convert month into numerical column

month_num = {'April':4, 'May':5, 'June':6, 'March':3}

df_match_batting['month'] = df_match_batting['month'].apply(lambda x : month_num[x])

# %%
df_match_batting.head(2)
# Out:
#   match_no match_city  year  month day          team_1               team_2  \
# 0        1  Cape Town  2009      4  18  Mumbai Indians  Chennai Super Kings
# 1        1  Cape Town  2009      4  18  Mumbai Indians  Chennai Super Kings
#
#             batsmen        wicket_status   R     B    M  fours  sixes      SR  \
# 0     ST Jayasuriya  c Hayden b Thushara  26  20.0  NaN    5.0    0.0  130.00
# 1  SR Tendulkar (c)              not out  59  49.0  NaN    7.0    0.0  120.40
#
#     special_role dismissal_mode
# 0  normal player         caught
# 1        captain        not out

# %%
filter_ =  df_match_batting['year'] == 2013

df_match_batting[filter_]['match_no'].unique()
# Out:
# array(['1', '2nd match (N)', '3rd match (N)', '4th match (D/N)',
#        '5th match (N)', '6th match (D/N)', '7th match (N)',
#        '8th match (N)', '9th match (D/N)', '10th match (N)',
#        '11th match (N)', '12th match (D/N)', '13th match (N)',
#        '14th match (N)', '15th match (D/N)', '16th match (N)',
#        '17th match (D/N)', '18th match (N)', '19th match (N)',
#        '20th match (D/N)', '21', '22nd match (D/N)', '23rd match (N)',
#        '24th match (N)', '25th match (N)', '26th match (D/N)',
#        '27th match (N)', '28th match (D/N)', '29th match (N)',
#        '30th match (N)', '31', '32nd match (N)', '33rd match (N)',
#        '34th match (N)', '35th match (N)', '36th match (D/N)',
#        '37th match (N)', '38th match (D/N)', '39th match (N)',
#        '40th match (D/N)', '41', '42nd match (N)', '43rd match (D/N)',
#        '44th match (N)', '45th match (D/N)', '46th match (N)',
#        '47th match (N)', '48th match (N)', '49th match (D/N)',
#        '50th match (N)', '51', '52nd match (D/N)', '53rd match (N)',
#        '54th match (N)', '55th match (D/N)', '56th match (N)',
#        '57th match (N)', '58th match (D/N)', '59th match (N)',
#        '60th match (D/N)', '61', '62nd match (N)', '63rd match (D/N)',
#        '64th match (N)', '65th match (D/N)', '66th match (N)',
#        '67th match (N)', '68th match (N)', '69th match (D/N)',
#        '70th match (N)', '71', '72nd match (N)', 'Qualifier 1 (N)',
#        'Eliminator (N)', 'Qualifier 2 (N)', 'Final (N)'], dtype=object)

# %%
df_match_batting.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11546 entries, 0 to 11545
# Data columns (total 17 columns):
# match_no          11546 non-null object
# match_city        11546 non-null object
# year              11546 non-null int64
# month             11546 non-null int64
# day               11546 non-null object
# team_1            11546 non-null object
# team_2            11546 non-null object
# batsmen           11546 non-null object
# wicket_status     11546 non-null object
# R                 11546 non-null object
# B                 11540 non-null float64
# M                 6804 non-null object
# fours             11540 non-null float64
# sixes             11540 non-null float64
# SR                11540 non-null object
# special_role      11546 non-null object
# dismissal_mode    11546 non-null object
# dtypes: float64(3), int64(2), object(12)
# memory usage: 1.5+ MB

# %%
null_replacment_for_M = 0

df_match_batting['M'].fillna(null_replacment_for_M,inplace = True)
df_match_batting['B'].fillna(0,inplace = True)
df_match_batting['fours'].fillna(0,inplace = True)
df_match_batting['sixes'].fillna(0,inplace = True)
df_match_batting['SR'].fillna(0,inplace = True)

df_match_batting['R'].replace(to_replace = '-',value = 0,inplace = True)
df_match_batting['M'].replace(to_replace = '-',value = 0,inplace = True)
df_match_batting['B'].replace(to_replace = '-',value = 0,inplace = True)
df_match_batting['SR'].replace(to_replace = '-',value = 0,inplace = True)
df_match_batting['SR'] = df_match_batting['SR'].astype('float64')
df_match_batting['M'] = df_match_batting['M'].astype('float64')
df_match_batting['R'] = df_match_batting['R'].astype('float64')

# %%
df_match_batting.head()
# Out:
#   match_no match_city  year  month day          team_1               team_2  \
# 0        1  Cape Town  2009      4  18  Mumbai Indians  Chennai Super Kings
# 1        1  Cape Town  2009      4  18  Mumbai Indians  Chennai Super Kings
# 2        1  Cape Town  2009      4  18  Mumbai Indians  Chennai Super Kings
# 3        1  Cape Town  2009      4  18  Mumbai Indians  Chennai Super Kings
# 4        1  Cape Town  2009      4  18  Mumbai Indians  Chennai Super Kings
#
#             batsmen               wicket_status     R     B    M  fours  \
# 0     ST Jayasuriya         c Hayden b Thushara  26.0  20.0  0.0    5.0
# 1  SR Tendulkar (c)                     not out  59.0  49.0  0.0    7.0
# 2          S Dhawan              c Dhoni b Gony  22.0  21.0  0.0    2.0
# 3         JP Duminy                  c & b Gony   9.0   7.0  0.0    1.0
# 4          DJ Bravo  c Hayden b Joginder Sharma   5.0   4.0  0.0    1.0
#
#    sixes      SR   special_role dismissal_mode
# 0    0.0  130.00  normal player         caught
# 1    0.0  120.40        captain        not out
# 2    0.0  104.76  normal player         caught
# 3    0.0  128.57  normal player         caught
# 4    0.0  125.00  normal player         caught

# %%
# saving the final file in the folder
df_match_batting.to_csv('E:/Google_Drive_Contents/data/Final_data_files/ipl_batting.csv',index = False)

# %%
# let's load the database cred

data_base_cred = None
with open('E:/Azure_database_config.json','r') as F:
    data_base_cred = json.load(F)

# %%
def get_azure_database_connection(server,database,username,password):
    """
    This function will return an aws conn object for azure SQl Server database.
    return : AWS connection object
    """
    cnxn = None
    try:
        cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+ password)
        return cnxn
        
    except Exception as e:
        print(e)

# %%
def insert_data_into_database(db_connection,df):
    """
    This function will insert data into the database row by row.
    parameters :
    db_connection : database connection object
    df : pandas DataFrame which has data
    return : None
    """
    try:
        
         # get the cursor
        cur = db_connection.cursor()
        for i,row in tqdm(df.iterrows(),total = df.shape[0]):
            row_list = list(row) # for easy access
            # create insert statment
            Insert_Statment = f"""Insert into ipl_batting values('{row_list[0]}','{row_list[1]}',{row_list[2]},{row_list[3]},'{row_list[4]}','{row_list[5]}','{row_list[6]}','{row_list[7]}','{row_list[8]}',{row_list[9]},{row_list[10]},{row_list[11]},{row_list[12]},{row_list[13]},{row_list[14]},'{row_list[15]}','{row_list[16]}')"""
            
#             print(Insert_Statment)
            
#             break

            
            # execute the query
            cur.execute(Insert_Statment)
            # commit the connection
            db_connection.commit()


    except Exception as e:
        print(e)

# %%
SERVER = data_base_cred['server']
DATABASE = data_base_cred['database']
USERNAME = data_base_cred['username']
PASSWORD = data_base_cred['password']
db_connection = get_azure_database_connection(SERVER,DATABASE,USERNAME,PASSWORD)

# %%
insert_data_into_database(db_connection,df_match_batting.head(1000))
# Out:
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))

# %%
insert_data_into_database(db_connection,df_match_batting.iloc[1000:2000,])
# Out:
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))

# %%
insert_data_into_database(db_connection,df_match_batting.iloc[2000:3000,])
# Out:
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))

# %%
insert_data_into_database(db_connection,df_match_batting.iloc[3000:4000,])
# Out:
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))

# %%
insert_data_into_database(db_connection,df_match_batting.iloc[4000:5000,])
# Out:
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))

# %%
insert_data_into_database(db_connection,df_match_batting.iloc[5000:6000,])
# Out:
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))

# %%
insert_data_into_database(db_connection,df_match_batting.iloc[6000:7000,])
# Out:
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))

# %%
insert_data_into_database(db_connection,df_match_batting.iloc[7000:8000,])
# Out:
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))

# %%
insert_data_into_database(db_connection,df_match_batting.iloc[8000:9000,])
# Out:
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))

# %%
insert_data_into_database(db_connection,df_match_batting.iloc[9000:10000,])
# Out:
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))

# %%
insert_data_into_database(db_connection,df_match_batting.iloc[10000:11000,])
# Out:
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))

# %%
insert_data_into_database(db_connection,df_match_batting.iloc[11000:,])
# Out:
# HBox(children=(IntProgress(value=0, max=546), HTML(value='')))

# %%
db_connection.close()

# %%
pd.read_sql('Select * from ipl_batting',con = db_connection)
# Out:
#        innings_id            match_no match_city  year  month day  \
# 0               1                   1  Cape Town  2009      4  18
# 1               2                   1  Cape Town  2009      4  18
# 2               3                   1  Cape Town  2009      4  18
# 3               4                   1  Cape Town  2009      4  18
# 4               5                   1  Cape Town  2009      4  18
# 5               6                   1  Cape Town  2009      4  18
# 6               7                   1  Cape Town  2009      4  18
# 7               8                   1  Cape Town  2009      4  18
# 8               9                   1  Cape Town  2009      4  18
# 9              10                   1  Cape Town  2009      4  18
# 10             11                   1  Cape Town  2009      4  18
# 11             12                   1  Cape Town  2009      4  18
# 12             13                   1  Cape Town  2009      4  18
# 13             14                   1  Cape Town  2009      4  18
# 14             15                   1  Cape Town  2009      4  18
# 15             16                   1  Cape Town  2009      4  18
# 16             17                   1  Cape Town  2009      4  18
# 17             18                   1  Cape Town  2009      4  18
# 18             19     2nd match (D/N)  Cape Town  2009      4  18
# 19             20     2nd match (D/N)  Cape Town  2009      4  18
# 20             21     2nd match (D/N)  Cape Town  2009      4  18
# 21             22     2nd match (D/N)  Cape Town  2009      4  18
# 22             23     2nd match (D/N)  Cape Town  2009      4  18
# 23             24     2nd match (D/N)  Cape Town  2009      4  18
# 24             25     2nd match (D/N)  Cape Town  2009      4  18
# 25             26     2nd match (D/N)  Cape Town  2009      4  18
# 26             27     2nd match (D/N)  Cape Town  2009      4  18
# 27             28     2nd match (D/N)  Cape Town  2009      4  18
# 28             29     2nd match (D/N)  Cape Town  2009      4  18
# 29             30     2nd match (D/N)  Cape Town  2009      4  18
# ...           ...                 ...        ...   ...    ...  ..
# 11516       11517                   1     Mumbai  2008      5  30
# 11517       11518  2nd Semi-Final (N)     Mumbai  2008      5  31
# 11518       11519  2nd Semi-Final (N)     Mumbai  2008      5  31
# 11519       11520  2nd Semi-Final (N)     Mumbai  2008      5  31
# 11520       11521  2nd Semi-Final (N)     Mumbai  2008      5  31
# 11521       11522  2nd Semi-Final (N)     Mumbai  2008      5  31
# 11522       11523  2nd Semi-Final (N)     Mumbai  2008      5  31
# 11523       11524  2nd Semi-Final (N)     Mumbai  2008      5  31
# 11524       11525  2nd Semi-Final (N)     Mumbai  2008      5  31
# 11525       11526  2nd Semi-Final (N)     Mumbai  2008      5  31
# 11526       11527  2nd Semi-Final (N)     Mumbai  2008      5  31
# 11527       11528  2nd Semi-Final (N)     Mumbai  2008      5  31
# 11528       11529  2nd Semi-Final (N)     Mumbai  2008      5  31
# 11529       11530  2nd Semi-Final (N)     Mumbai  2008      5  31
# 11530       11531           Final (N)     Mumbai  2008      6   1
# 11531       11532           Final (N)     Mumbai  2008      6   1
# 11532       11533           Final (N)     Mumbai  2008      6   1
# 11533       11534           Final (N)     Mumbai  2008      6   1
# 11534       11535           Final (N)     Mumbai  2008      6   1
# 11535       11536           Final (N)     Mumbai  2008      6   1
# 11536       11537           Final (N)     Mumbai  2008      6   1
# 11537       11538           Final (N)     Mumbai  2008      6   1
# 11538       11539           Final (N)     Mumbai  2008      6   1
# 11539       11540           Final (N)     Mumbai  2008      6   1
# 11540       11541           Final (N)     Mumbai  2008      6   1
# 11541       11542           Final (N)     Mumbai  2008      6   1
# 11542       11543           Final (N)     Mumbai  2008      6   1
# 11543       11544           Final (N)     Mumbai  2008      6   1
# 11544       11545           Final (N)     Mumbai  2008      6   1
# 11545       11546           Final (N)     Mumbai  2008      6   1
#
#                             team_1               team_2           batsman  \
# 0                   Mumbai Indians  Chennai Super Kings     ST Jayasuriya
# 1                   Mumbai Indians  Chennai Super Kings  SR Tendulkar (c)
# 2                   Mumbai Indians  Chennai Super Kings          S Dhawan
# 3                   Mumbai Indians  Chennai Super Kings         JP Duminy
# 4                   Mumbai Indians  Chennai Super Kings          DJ Bravo
# 5                   Mumbai Indians  Chennai Super Kings          AM Nayar
# 6                   Mumbai Indians  Chennai Super Kings   Harbhajan Singh
# 7                   Mumbai Indians  Chennai Super Kings            Z Khan
# 8                   Mumbai Indians  Chennai Super Kings         PR Shah †
# 9                   Mumbai Indians  Chennai Super Kings        PA Patel †
# 10                  Mumbai Indians  Chennai Super Kings         ML Hayden
# 11                  Mumbai Indians  Chennai Super Kings          SK Raina
# 12                  Mumbai Indians  Chennai Super Kings        A Flintoff
# 13                  Mumbai Indians  Chennai Super Kings      MS Dhoni (c)
# 14                  Mumbai Indians  Chennai Super Kings          JDP Oram
# 15                  Mumbai Indians  Chennai Super Kings       S Badrinath
# 16                  Mumbai Indians  Chennai Super Kings   Joginder Sharma
# 17                  Mumbai Indians  Chennai Super Kings        T Thushara
# 18     Royal Challengers Bangalore     Rajasthan Royals          JD Ryder
# 19     Royal Challengers Bangalore     Rajasthan Royals      RV Uthappa †
# 20     Royal Challengers Bangalore     Rajasthan Royals       LRPL Taylor
# 21     Royal Challengers Bangalore     Rajasthan Royals  KP Pietersen (c)
# 22     Royal Challengers Bangalore     Rajasthan Royals          R Dravid
# 23     Royal Challengers Bangalore     Rajasthan Royals           V Kohli
# 24     Royal Challengers Bangalore     Rajasthan Royals           B Akhil
# 25     Royal Challengers Bangalore     Rajasthan Royals           P Kumar
# 26     Royal Challengers Bangalore     Rajasthan Royals     R Vinay Kumar
# 27     Royal Challengers Bangalore     Rajasthan Royals          DW Steyn
# 28     Royal Challengers Bangalore     Rajasthan Royals          GC Smith
# 29     Royal Challengers Bangalore     Rajasthan Royals       SA Asnodkar
# ...                            ...                  ...               ...
# 11516             Rajasthan Royals     Delhi Daredevils        GD McGrath
# 11517              Kings XI Punjab  Chennai Super Kings          SE Marsh
# 11518              Kings XI Punjab  Chennai Super Kings          JR Hopes
# 11519              Kings XI Punjab  Chennai Super Kings   KC Sangakkara †
# 11520              Kings XI Punjab  Chennai Super Kings  Yuvraj Singh (c)
# 11521              Kings XI Punjab  Chennai Super Kings  DPMD Jayawardene
# 11522              Kings XI Punjab  Chennai Super Kings         IK Pathan
# 11523              Kings XI Punjab  Chennai Super Kings           WA Mota
# 11524              Kings XI Punjab  Chennai Super Kings         PP Chawla
# 11525              Kings XI Punjab  Chennai Super Kings          RR Powar
# 11526              Kings XI Punjab  Chennai Super Kings       S Sreesanth
# 11527              Kings XI Punjab  Chennai Super Kings        PA Patel †
# 11528              Kings XI Punjab  Chennai Super Kings          S Vidyut
# 11529              Kings XI Punjab  Chennai Super Kings          SK Raina
# 11530          Chennai Super Kings     Rajasthan Royals        PA Patel †
# 11531          Chennai Super Kings     Rajasthan Royals          S Vidyut
# 11532          Chennai Super Kings     Rajasthan Royals          SK Raina
# 11533          Chennai Super Kings     Rajasthan Royals         JA Morkel
# 11534          Chennai Super Kings     Rajasthan Royals      MS Dhoni (c)
# 11535          Chennai Super Kings     Rajasthan Royals     CK Kapugedera
# 11536          Chennai Super Kings     Rajasthan Royals       S Badrinath
# 11537          Chennai Super Kings     Rajasthan Royals          NK Patel
# 11538          Chennai Super Kings     Rajasthan Royals       SA Asnodkar
# 11539          Chennai Super Kings     Rajasthan Royals    Kamran Akmal †
# 11540          Chennai Super Kings     Rajasthan Royals         SR Watson
# 11541          Chennai Super Kings     Rajasthan Royals         YK Pathan
# 11542          Chennai Super Kings     Rajasthan Royals            M Kaif
# 11543          Chennai Super Kings     Rajasthan Royals         RA Jadeja
# 11544          Chennai Super Kings     Rajasthan Royals      SK Warne (c)
# 11545          Chennai Super Kings     Rajasthan Royals     Sohail Tanvir
#
#                     wicket_status  runs  balls  M  fours  sixes  strike_rate  \
# 0             c Hayden b Thushara    26     20  0      5    0.0       130.00
# 1                         not out    59     49  0      7    0.0       120.40
# 2                  c Dhoni b Gony    22     21  0      2    0.0       104.76
# 3                      c & b Gony     9      7  0      1    0.0       128.57
# 4      c Hayden b Joginder Sharma     5      4  0      1    0.0       125.00
# 5               c Thushara b Oram    35     14  0      2    3.0       250.00
# 6                  run out (Oram)     4      2  0      1    0.0       200.00
# 7             c Ashwin b Flintoff     2      3  0      0    0.0        66.66
# 8                         not out     0      0  0      0    0.0         0.00
# 9           c Tendulkar b Malinga     0      2  0      0    0.0         0.00
# 10            c Khan b Jayasuriya    44     35  0      6    1.0       125.71
# 11                 c Raje b Bravo     8      9  0      1    0.0        88.88
# 12          c & b Harbhajan Singh    24     23  0      2    1.0       104.34
# 13                      b Malinga    36     26  0      1    2.0       138.46
# 14           c †Shah b Jayasuriya     8      6  0      0    1.0       133.33
# 15              c Bravo b Malinga     0      2  0      0    0.0         0.00
# 16                        not out    16     15  0      0    1.0       106.66
# 17                        not out     1      2  0      0    0.0        50.00
# 18         c †Rawat b Mascarenhas     0      2  0      0    0.0         0.00
# 19         c †Rawat b Mascarenhas     3     10  0      0    0.0        30.00
# 20                  b Mascarenhas     0      1  0      0    0.0         0.00
# 21         c NK Patel b Henderson    32     30  0      4    0.0       106.66
# 22             c Warne b MM Patel    66     48  0      8    1.0       137.50
# 23                        b Warne     3      8  0      0    0.0        37.50
# 24                        b Warne     9      9  0      1    0.0       100.00
# 25                 c & b MM Patel     8     10  0      0    1.0        80.00
# 26                        not out     8      2  0      2    0.0       400.00
# 27                        not out     0      0  0      0    0.0         0.00
# 28               c Dravid b Kumar     2     11  0      0    0.0        18.18
# 29                c Kohli b Kumar     0      2  0      0    0.0         0.00
# ...                           ...   ...    ... ..    ...    ...          ...
# 11516                     not out     4      3  0      1    0.0       133.33
# 11517                     b Ntini    23     17  0      3    1.0       135.29
# 11518            c †Patel b Ntini     2      5  0      0    0.0        40.00
# 11519             c †Patel b Gony     3      4  0      0    0.0        75.00
# 11520       c Muralitharan b Gony     4      8  0      0    0.0        50.00
# 11521           c †Patel b Morkel     8     10  0      1    0.0        80.00
# 11522        run out (Ntini/Gony)     3     12  0      0    0.0        25.00
# 11523            c Raina b Morkel    25     26  0      2    0.0        96.15
# 11524              b Muralitharan    12     15  0      1    0.0        80.00
# 11525                     not out    28     21  0      4    1.0       133.33
# 11526                     not out     0      2  0      0    0.0         0.00
# 11527                     not out    51     48  0      8    0.0       106.25
# 11528             c Mota b Pathan     6      7  0      1    0.0        85.71
# 11529                     not out    55     34  0      4    4.0       161.76
# 11530    c †Kamran Akmal b Pathan    38     33  0      5    0.0       115.15
# 11531           c Jadeja b Pathan    16     14  0      1    1.0       114.28
# 11532           c Jadeja b Watson    43     30  0      1    2.0       143.33
# 11533    c †Kamran Akmal b Pathan    16     13  0      0    2.0       123.07
# 11534                     not out    29     17  0      1    2.0       170.58
# 11535  c Asnodkar b Sohail Tanvir     8     12  0      0    0.0        66.66
# 11536                     not out     6      2  0      1    0.0       300.00
# 11537                      b Gony     2     11  0      0    0.0        18.18
# 11538            c Raina b Morkel    28     20  0      4    0.0       140.00
# 11539             run out (Ntini)     6      7  0      1    0.0        85.71
# 11540              b Muralitharan    28     19  0      3    0.0       147.36
# 11541             run out (Raina)    56     39  0      3    4.0       143.58
# 11542      c Dhoni b Muralitharan    12      9  0      0    1.0       133.33
# 11543       c Kapugedera b Morkel     0      1  0      0    0.0         0.00
# 11544                     not out     9      9  0      1    0.0       100.00
# 11545                     not out     9      7  0      0    0.0       128.57
#
#         special_role dismissal_mode
# 0      normal player         caught
# 1            captain        not out
# 2      normal player         caught
# 3      normal player         caught
# 4      normal player         caught
# 5      normal player         caught
# 6      normal player        run out
# 7      normal player         caught
# 8      wicket keeper        not out
# 9      wicket keeper         caught
# 10     normal player         caught
# 11     normal player         caught
# 12     normal player         caught
# 13           captain         bowled
# 14     normal player         caught
# 15     normal player         caught
# 16     normal player        not out
# 17     normal player        not out
# 18     normal player         caught
# 19     wicket keeper         caught
# 20     normal player         bowled
# 21           captain         caught
# 22     normal player         caught
# 23     normal player         bowled
# 24     normal player         bowled
# 25     normal player         caught
# 26     normal player        not out
# 27     normal player        not out
# 28     normal player         caught
# 29     normal player         caught
# ...              ...            ...
# 11516  normal player        not out
# 11517  normal player         bowled
# 11518  normal player         caught
# 11519  wicket keeper         caught
# 11520        captain         caught
# 11521  normal player         caught
# 11522  normal player        run out
# 11523  normal player         caught
# 11524  normal player         bowled
# 11525  normal player        not out
# 11526  normal player        not out
# 11527  wicket keeper        not out
# 11528  normal player         caught
# 11529  normal player        not out
# 11530  wicket keeper         caught
# 11531  normal player         caught
# 11532  normal player         caught
# 11533  normal player         caught
# 11534        captain        not out
# 11535  normal player         caught
# 11536  normal player        not out
# 11537  normal player         bowled
# 11538  normal player         caught
# 11539  wicket keeper        run out
# 11540  normal player         bowled
# 11541  normal player        run out
# 11542  normal player         caught
# 11543  normal player         caught
# 11544        captain        not out
# 11545  normal player        not out
#
# [11546 rows x 18 columns]
