# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pip install azure-storage-blob
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient
import json
DATA_LAKE_FOLDER_PATH = "/content/drive/My Drive/data/Final_data_files"
connection_string  = None
container_name = None

with open("/content/drive/My Drive/data/Azure_blob_info.json",'r') as F:
    info = json.load(F)
    connection_string = info['connection_string']
    container_name = info['container_name']

# print(connection_string)
# print(container_name)
# Out:
# Requirement already satisfied: azure-storage-blob in /usr/local/lib/python3.6/dist-packages (12.3.0)
# Requirement already satisfied: cryptography>=2.1.4 in /usr/local/lib/python3.6/dist-packages (from azure-storage-blob) (2.8)
# Requirement already satisfied: msrest>=0.6.10 in /usr/local/lib/python3.6/dist-packages (from azure-storage-blob) (0.6.11)
# Requirement already satisfied: azure-core<2.0.0,>=1.2.2 in /usr/local/lib/python3.6/dist-packages (from azure-storage-blob) (1.3.0)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /usr/local/lib/python3.6/dist-packages (from cryptography>=2.1.4->azure-storage-blob) (1.14.0)
# Requirement already satisfied: six>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from cryptography>=2.1.4->azure-storage-blob) (1.12.0)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /usr/local/lib/python3.6/dist-packages (from msrest>=0.6.10->azure-storage-blob) (1.3.0)
# Requirement already satisfied: requests~=2.16 in /usr/local/lib/python3.6/dist-packages (from msrest>=0.6.10->azure-storage-blob) (2.21.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from msrest>=0.6.10->azure-storage-blob) (2019.11.28)
# Requirement already satisfied: isodate>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from msrest>=0.6.10->azure-storage-blob) (0.6.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi!=1.11.3,>=1.8->cryptography>=2.1.4->azure-storage-blob) (2.19)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.10->azure-storage-blob) (3.1.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests~=2.16->msrest>=0.6.10->azure-storage-blob) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests~=2.16->msrest>=0.6.10->azure-storage-blob) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests~=2.16->msrest>=0.6.10->azure-storage-blob) (2.8)

# %%
def list_blobs(connection_string,container_name):
    """
    This function will list out whatever files or folder are there in the container
    """
    try:
        blob_service_client = BlobServiceClient.from_connection_string(connection_string)

        container_client = blob_service_client.get_container_client(container_name)

        blob_list = container_client.list_blobs()

        for blob in blob_list:
            print("\t" + blob.name)

    except Exception as e:
        print('Exception :\n {}'.format(e))

# %%
def store_to_blob(connection_string,container_name,path_to_csv,folder_name,file_name):
    """
    This function will store a df in azure blob storage,
    connection_string : connection_string for connecting to the blob
    container : container_name in which we have blob
    path_to_csv : csv file path , which you want to upload to blob
    folder_name : if there is a folder in container in which you want to store the file,
    file_name : what will be the name of the file in the blob
    """
    try:
        blob_service_client = BlobServiceClient.from_connection_string(connection_string)

        container_client = blob_service_client.get_container_client(container_name) 

        blob_client = blob_service_client.get_blob_client(container=container_name, blob= f"{folder_name}/{file_name}")

        with open(path_to_csv,'rb') as F:
            blob_client.upload_blob(F)

        print('File uploaded....')

    except Exception as e:
        print('Exception :\n{}'.format(e))

# %%
store_to_blob(connection_string,container_name,
              path_to_csv=DATA_LAKE_FOLDER_PATH+'/All_IPL_team_summary.csv',folder_name = 'raw',file_name = 'ipl_summary.csv')
# Out:
# File uploaded....

# %%
list_blobs(connection_string,container_name)
# Out:
# 	final
# 	imgs
# 	imgs/team-logos
# 	imgs/team-logos/actual-ranks.png
# 	imgs/team-logos/csk.png
# 	imgs/team-logos/dc.png
# 	imgs/team-logos/kkr.png
# 	imgs/team-logos/kxp.png
# 	imgs/team-logos/mi.png
# 	imgs/team-logos/normal-ranks.png
# 	imgs/team-logos/rcb.png
# 	imgs/team-logos/rr.png
# 	imgs/team-logos/srh.png
# 	ipl_batting.csv
# 	ipl_matches.csv
# 	ipl_players.csv
# 	ipl_team.csv
# 	raw
# 	raw/ipl_batting.csv
# 	raw/ipl_bowling.csv
# 	raw/ipl_matches.csv
# 	raw/ipl_players.csv
# 	raw/ipl_summary.csv
# 	raw/ipl_teams.csv
