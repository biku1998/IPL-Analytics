# %%
DATA_SOURCE = "./ipl-analytics/raw/"
DATA_DEST = "./ipl-analytics/final/"

# %%
import pandas as pd
import numpy as np
import datetime
pd.options.display.max_columns = 100
pd.options.display.max_rows = 500

# %%
df_teams = pd.read_csv(DATA_SOURCE+'ipl_teams.csv')

# %%
df_teams.head(10)
# Out:
#                           Team                         City  \
# 0          Chennai Super Kings          Chennai, Tamil Nadu
# 1               Delhi Capitals                   Delhi, NCR
# 2              Kings XI Punjab  Mohali (Chandigarh), Punjab
# 3        Kolkata Knight Riders         Kolkata, West Bengal
# 4               Mumbai Indians          Mumbai, Maharashtra
# 5             Rajasthan Royals            Jaipur, Rajasthan
# 6  Royal Challengers Bangalore         Bengaluru, Karnataka
# 7          Sunrisers Hyderabad         Hyderabad, Telengana
# 8         Kochi Tuskers Kerala                Kochi, Kerala
# 9          Pune Warriors India            Pune, Maharashtra
#
#                                          Home_ground  Debut          Captain  \
# 0                          M. A. Chidambaram Stadium   2008         MS Dhoni
# 1                               Arun Jaitley Stadium   2008     Shreyas Iyer
# 2          PCA Stadium, MohaliHolkar Stadium, Indore   2008      K. L. Rahul
# 3                                       Eden Gardens   2008   Dinesh Karthik
# 4                                   Wankhede Stadium   2008     Rohit Sharma
# 5                             Sawai Mansingh Stadium   2008      Steve Smith
# 6                             M. Chinnaswamy Stadium   2008      Virat Kohli
# 7         Rajiv Gandhi International Cricket Stadium   2013  Kane Williamson
# 8                           Jawaharlal Nehru Stadium   2010    Parthiv Patel
# 9  DY Patil Stadium, Maharashtra Cricket Associat...   2010      Aaron Finch
#
#                                                Owner  Dissolved
# 0                                      India Cements          0
# 1                            GMR Group and JSW Group          0
# 2  Preity Zinta, Ness Wadia, Mohit Burman, Karan ...          0
# 3         Red Chillies Entertainment and Mehta Group          0
# 4                                Reliance Industries          0
# 5                                       Manoj Badale          0
# 6                                     United Spirits          0
# 7                                     Sun TV Network          0
# 8                              Rendezvous Consortium       2011
# 9                                        Subrata Roy       2014

# %%
df_teams.to_csv(DATA_DEST+'ipl_teams.csv',index=False)
