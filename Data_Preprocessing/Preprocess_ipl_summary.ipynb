# %%
DATA_SOURCE = "./ipl-analytics/raw/"
DATA_DEST = "./ipl-analytics/final/"

# %%
import pandas as pd
import numpy as np
import datetime
pd.options.display.max_columns = 100
pd.options.display.max_rows = 500

# %%
df_summary = pd.read_csv(DATA_SOURCE+'ipl_summary.csv')

# %%
df_summary.head(10)
# Out:
#   Abbrev  Lost  N/R  Played Short Name                         Team  Won  \
# 0    CSK     7    0      16    Chennai          Chennai Super Kings    9
# 1    DCH    12    0      14     Deccan              Deccan Chargers    2
# 2    DDV     7    0      14      Delhi             Delhi Daredevils    7
# 3    KXI     5    0      15     Punjab              Kings XI Punjab   10
# 4    KKR     7    0      13    Kolkata        Kolkata Knight Riders    6
# 5    MIN     7    0      14     Mumbai               Mumbai Indians    7
# 6    RRO     3    0      16  Rajasthan             Rajasthan Royals   13
# 7    RCB    10    0      14  Bangalore  Royal Challengers Bangalore    4
# 8    CSK     6    0      14    Chennai          Chennai Super Kings    8
# 9    DCH     7    0      16     Deccan              Deccan Chargers    9
#
#      year
# 0  2008.0
# 1  2008.0
# 2  2008.0
# 3  2008.0
# 4  2008.0
# 5  2008.0
# 6  2008.0
# 7  2008.0
# 8  2009.0
# 9  2009.0

# %%
df_summary.to_csv(DATA_DEST+'ipl_summary.csv',index=False)
